# %%
import pandas as pd
df = pd.read_csv('trafficp.csv')

# %%
df.drop("Date and Time", axis=1)  # To delete single column
# Out:
#      Four Wheelers  Bus  Truck  Mini Bus/ Mini Truck  Tractor with trolly  \
# 0               79    2      7                    56                   26
# 1               56    2      4                    49                   13
# 2               76    1      5                    53                   18
# 3               51    2     15                    34                   13
# 4               39    1      9                    31                    8
# 5               41    1     12                    29                   11
# 6               51    1      8                    28                    7
# 7               64    3      6                    22                    6
# 8               53    7     12                    19                   10
# 9               71    3     15                    28                   12
# 10              42    4     12                    25                    3
# 11              31    2      1                    18                    4
# ...

# %%
df.drop(columns=["Total","Date and Time"])  # To delete columns
# Out:
#      Four Wheelers  Bus  Truck  Mini Bus/ Mini Truck  Tractor with trolly  \
# 0               79    2      7                    56                   26
# 1               56    2      4                    49                   13
# 2               76    1      5                    53                   18
# 3               51    2     15                    34                   13
# 4               39    1      9                    31                    8
# 5               41    1     12                    29                   11
# 6               51    1      8                    28                    7
# 7               64    3      6                    22                    6
# 8               53    7     12                    19                   10
# 9               71    3     15                    28                   12
# 10              42    4     12                    25                    3
# 11              31    2      1                    18                    4
# ...

# %%
df.drop(df.index[:10])  # To delete more than one rows
# Out:
#                     Date and Time  Four Wheelers  Bus  Truck  \
# 10        11-06-2011 7:00-8:00 PM             42    4     12
# 11        11-06-2011 8:00-9:00 PM             31    2      1
# 12       11-06-2011 9:00-10:00 PM             28    2      4
# 13      11-06-2011 10:00-11:00 PM              8    1      7
# 14      11-06-2011 11:00-12:00 AM             23    2      1
# 15       12-06-2011 12:00-1:00 AM             10    0      1
# 16        12-06-2011 1:00-2:00 AM              4    0      1
# 17        12-06-2011 2:00-3:00 AM              2    0      3
# 18        12-06-2011 3:00-4:00 AM              6    0      3
# 19        12-06-2011 4:00-5:00 AM             12    1      3
# 20        12-06-2011 5:00-6:00 AM             20    1      9
# 21        12-06-2011 6:00-7:00 AM             26    1      5
# 22        12-06-2011 7:00-8:00 AM             46    2     10
# 23        12-06-2011 8:00-9:00 AM             82    2      5
# ...

# %%
df.drop(0)  # to delete single row
# Out:
#                     Date and Time  Four Wheelers  Bus  Truck  \
# 1       11-06-2011 10:00-11:00 AM             56    2      4
# 2    11-06-2011 11:00-12:00 Noon              76    1      5
# 3        11-06-2011 12:00-1:00 PM             51    2     15
# 4         11-06-2011 1:00-2:00 PM             39    1      9
# 5         11-06-2011 2:00-3:00 PM             41    1     12
# 6         11-06-2011 3:00-4:00 PM             51    1      8
# 7         11-06-2011 4:00-5:00 PM             64    3      6
# 8         11-06-2011 5:00-6:00 PM             53    7     12
# 9         11-06-2011 6:00-7:00 PM             71    3     15
# 10        11-06-2011 7:00-8:00 PM             42    4     12
# 11        11-06-2011 8:00-9:00 PM             31    2      1
# 12       11-06-2011 9:00-10:00 PM             28    2      4
# 13      11-06-2011 10:00-11:00 PM              8    1      7
# 14      11-06-2011 11:00-12:00 AM             23    2      1
# ...
